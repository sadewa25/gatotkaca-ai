# %% [markdown]
# ## Daftar Ibukota Provinsi di Indonesia

# %%
import requests

url = "https://id.wikipedia.org/wiki/Daftar_ibu_kota_provinsi_di_Indonesia"
response = requests.get(url)
wikisite = response.text
wikisite
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="id" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>Daftar ibu kota provinsi di Indonesia - Wikipedia bahasa Indonesia, ensiklopedia bebas</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available";var cookie=document.cookie.match(/(?:^|; )idwikimwclientpreferences=([^;]+)/);if(cookie){cookie[1].split(\'%2C\').forEach(function(pref){className=className.replace(new RegExp(\'(^| )\'+pref.replace(/-clientpref-\\w+$|[^\\w-]+/g,\'\')+\'-clientpref-\\\\w+( |$)\'),\'$1\'+pref+\'$2\');});}document.documentElement.className=className;}());RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.",".\\t,"],\n"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","Januari","Februari","Maret","April","Mei","Juni","Juli","Agustus","September","Oktober","November","Desember"],"wgRequestId":"af8cfc01-c8fc-467e-9aaa-79f7ada69d66","wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Daftar_ibu_kota_provinsi_di_Indonesia","wgTitle":"Daftar ibu kota provinsi di Indonesia","wgCurRevisionId":25698746,"wgRevisionId":25698746,"wgArticleId":422184,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Halaman dengan kesalahan referensi","Artikel dengan pranala luar nonaktif","Artikel dengan pranala luar nonaktif permanen","Ibu kota provinsi di Indonesia","Daftar tempat di Indonesia","Daftar ibu kota","Daftar provinsi di Indonesia"],"wgPageViewLanguage":"id","wgPageContentLanguage":"id","wgPageContentModel":"wikitext","wgRelevantPageName":"Daftar_ibu_kota_provinsi_di_Indonesia",\n"wgRelevantArticleId":422184,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgNoticeProject":"wikipedia","wgCiteReferencePreviewsActive":false,"wgFlaggedRevsParams":{"tags":{"accuracy":{"levels":2}}},"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":6,"wgVisualEditor":{"pageLanguageCode":"id","pageLanguageDir":"ltr","pageVariantFallbacks":"id"},"wgMFDisplayWikibaseDescriptions":{"search":true,"watchlist":true,"tagline":true,"nearby":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":80000,"wgULSCurrentAutonym":"Bahasa Indonesia","wgRelatedArticlesCompat":[],"wgCentralAuthMobileDomain":false,"wgEditSubmitButtonLabelPublish":true,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":false,"wgVector2022LanguageInHeader":true,"wgULSisLanguageSelectorEmpty":false,"wgWikibaseItemId":"Q4263115","wgCheckUserClientHintsHeadersJsApi":["architecture","bitness","brands",\n"fullVersionList","mobile","model","platform","platformVersion"],"GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false,"wgGEStructuredTaskRejectionReasonTextInputEnabled":false,"wgGELevelingUpEnabledForUser":false};R ...

# %%
from bs4 import BeautifulSoup
import re

soup = BeautifulSoup(wikisite, 'html.parser')
tbody = soup.find('table').find('tbody')

indProv = []

# Check if tbody exists
if tbody:
    # Iterate over the elements inside tbody
    for tr in tbody.find_all('tr'):  # Assuming you want to get all rows
        # Get the text inside the td
        td = tr.find_all('td')
        if td and td[0].get_text(strip=True) != '-':
            areas = td[6].get_text(strip=True)
            cleaned_areas = re.sub(r'\[.*?\]', '', areas).strip()

            capital = td[2].get_text(strip=True)
            cleaned_capital = re.sub(r'\[.*?\]', '', capital).strip()

            indProv.append({
                'id': td[0].get_text(strip=True),
                'nama': td[1].get_text(strip=True),
                'ibukota': cleaned_capital,
                'luas_wilayah': cleaned_areas,
                'ipm': td[7].get_text(strip=True)
            })
else:
    print("No tbody found")

# %%
indProv, len(indProv)
# Out:
# ([{'id': '1',
#    'nama': 'Aceh',
#    'ibukota': 'Banda Aceh',
#    'luas_wilayah': '61,36',
#    'ipm': '85,71'},
#   {'id': '2',
#    'nama': 'Sumatera Utara',
#    'ibukota': 'Medan',
#    'luas_wilayah': '265,10',
#    'ipm': '81,21'},
#   {'id': '3',
#    'nama': 'Sumatera Barat',
#    'ibukota': 'Padang',
#    'luas_wilayah': '694,93',
#    'ipm': '82,90'},
#   {'id': '4',
#    'nama': 'Riau',
#    'ibukota': 'Pekanbaru',
#    'luas_wilayah': '632,26',
#    'ipm': '81,58'},
#   {'id': '5',
#    'nama': 'Jambi',
#    'ibukota': 'Jambi',
#    'luas_wilayah': '205,58',
#    'ipm': '79,12'},
#   {'id': '6',
#    'nama': 'Sumatera Selatan',
#    'ibukota': 'Palembang',
#    'luas_wilayah': '400,61',
#    'ipm': '78,72'},
#   {'id': '7',
#    'nama': 'Bengkulu',
#    'ibukota': 'Bengkulu',
#    'luas_wilayah': '151,70',
#    'ipm': '80,54'},
#   {'id': '8',
#    'nama': 'Lampung',
#    'ibukota': 'Bandar Lampung',
#    'luas_wilayah': '197,22',
#    'ipm': '77,58'},
#   {'id': '9',
#    'nama': 'Kepulauan Bangka Belitung',
#    'ibukota': 'Pangkalpinang',
#    'luas_wilayah': '118,41',
#    'ipm': '78,57'},
#   {'id': '10',
#    'nama': 'Kepulauan Riau',
#    'ibukota': 'Tanjungpinang',
#    'luas_wilayah': '150,86',
#    'ipm': '78,93'},
#   {'id': '11',
#    'nama': 'Daerah Khusus Ibukota Jakarta',
#    'ibukota': 'Tak ada',
#    'luas_wilayah': '662,33',
#    'ipm': '81,56'},
#   {'id': '12',
#    'nama': 'Jawa Barat',
#    'ibukota': 'Bandung',
#    'luas_wilayah': '167,31',
#    'ipm': '81,96'},
#   {'id': '13',
#    'nama': 'Jawa Tengah',
#    'ibukota': 'Semarang',
#    'luas_wilayah': '373,70',
#    'ipm': '83,55'},
#   {'id': '14',
#    'nama': 'Daerah Istimewa Yogyakarta',
#    'ibukota': 'Yogyakarta',
#    'luas_wilayah': '32,50',
#    'ipm': '87,18'},
#   {'id': '15',
#    'nama': 'Jawa Timur',
#    'ibukota': 'Surabaya',
#    'luas_wilayah': '326,81',
#    'ipm': '82,31'},
#   {'id': '16',
#    'nama': 'Banten',
#    'ibukota': 'Serang',
#    'luas_wilayah': '266,74',
#    'ipm': '72,44'},
#   {'id': '17',
#    'nama': 'Bali',
#    'ibukota': 'Denpasar',
#    'luas_wilayah': '127,78',
#    'ipm': '84,03'},
#   {'id': '18',
#    'nama': 'Nusa Tenggara Barat',
#    'ibukota': 'Mataram',
#    'luas_wilayah': '61,30',
#    'ipm': '79,14'},
#   {'id': '19',
#    'nama': 'Nusa Tenggara Timur',
#    'ibukota': 'Kupang',
#    'luas_wilayah': '180,27',
#    'ipm': '79,74'},
#   {'id': '20',
#    'nama': 'Kalimantan Barat',
#    'ibukota': 'Pontianak',
#    'luas_wilayah': '107,82',
#    'ipm': '79,93'},
#   {'id': '21',
#    'nama': 'Kalimantan Tengah',
#    'ibukota': 'Palangka Raya',
#    'luas_wilayah': '2.678,51',
#    'ipm': '80,82'},
#   {'id': '22',
#    'nama': 'Kalimantan Selatan',
#    'ibukota': 'Banjarbaru',
#    'luas_wilayah': '72,67',
#    'ipm': '79,26'},
#   {'id': '23',
#    'nama': 'Kalimantan Timur',
#    'ibukota': 'Samarinda',
#    'luas_wilayah': '718,00',
#    'ipm': '80,76'},
#   {'id': '24',
#    'nama': 'Kalimantan Utara',
#    'ibukota': 'Tanjung Selor',
#    'luas_wilayah': '677,77',
#    'ipm': '71,80'},
#   {'id': '25',
#    'nama': 'Sulawesi Utara',
#    'ibukota': 'Manado',
#    'luas_wilayah': '157,26',
#    'ipm': '79,20'},
#   {'id': '26',
#    'nama': 'Sulawesi Tengah',
#    'ibukota': 'Palu',
#    'luas_wilayah': '395,06',
#    'ipm': '81,70'},
#   {'id': '27',
#    'nama': 'Sulawesi Selatan',
#    'ibukota': 'Makassar',
#    'luas_wilayah': '175,77',
#    'ipm': '82,66'},
#   {'id': '28',
#    'nama': 'Sulawesi Tenggara',
#    'ibukota': 'Kendari',
#    'luas_wilayah': '295,89',
#    'ipm': '84,15'},
#   {'id': '29',
#    'nama': 'Gorontalo',
#    'ibukota': 'Gorontalo',
#    'luas_wilayah': '65,96',
#    'ipm': '77,41'},
#   {'id': '30',
#    'nama': 'Sulawesi Barat',
#    'ibukota': 'Mamuju',
#    'luas_wilayah': '5.064,19',
#    'ipm': '68,32'},
#   {'id': '31',
#    'nama': 'Maluku',
#    'ibukota': 'Ambon',
#    'luas_wilayah': '359,45',
#    'ipm': '81,23'},
#   {'id': '32',
#    'nama': 'Maluku Utara',
#    'ibukota': 'Sofifi',
#    'luas_wilayah': '20,98',
#    'ipm': '70,99'},
#   {'id': '33',
#    'nama': 'Papua',
#    'ibukota': 'Jayapura',
#    'luas_wilayah': '940,00',
#    'ipm': '80,11'},
#   {'id': '34',
#    'nama': 'Papua Barat',
#    'ibukota': 'Manokwari',
#    'luas_wilayah': '',
#    'ipm': ''},
#   {'id': '35',
#    'nama': 'Papua Barat Daya',
#    'ibukota': 'Sorong',
#    'luas_wilayah': '',
#    'ipm': ''},
#   {'id': '36',
#    'nama': 'Papua Tengah',
#    'ibukota': 'Wanggar',
#    'luas_wilayah': '',
#    'ipm': ''},
#   {'id': '37',
#    'nama': 'Papua Pegunungan',
#    'ibukota': 'Walesi',
#    'luas_wilayah': '',
#    'ipm': ''},
#   {'id': '38',
#    'nama': 'Papua Selatan',
#    'ibukota': 'Salor',
#    'luas_wilayah': '',
#    'ipm': ''}],
#  38)

# %%
# there are missing values in ibukota jakarta
indProv[10]['ibukota'] = 'Jakarta'
print(indProv[10])
# Out:
# {'id': '11', 'nama': 'Daerah Khusus Ibukota Jakarta', 'ibukota': 'Jakarta', 'luas_wilayah': '662,33', 'ipm': '81,56'}

# %%
# change palang karaya to palangkaraya
indProv[20]['ibukota'] = indProv[20]['ibukota'].replace(" ", "")
print(indProv[20])
# Out:
# {'id': '21', 'nama': 'Kalimantan Tengah', 'ibukota': 'PalangkaRaya', 'luas_wilayah': '2.678,51', 'ipm': '80,82'}

# %%
# remove walesi because there are no geocoding information
indProv[36]
# Out:
# {'id': '37',
#  'nama': 'Papua Pegunungan',
#  'ibukota': 'Walesi',
#  'luas_wilayah': '',
#  'ipm': ''}

# %%
indProv.remove(indProv[36])
len(indProv)
# Out:
# 37

# %%
# Palang Karaya pada wikipedia seharusnya palangkaraya, dan data wales ibukota papua pegununga tidak ada pada geocoding longlat
# ibukota jakarta juga tidak ada

# %%
import numpy as np

indProv_array = np.array(indProv)
np.save('temp/ind_prov.npy', indProv_array)

# %% [markdown]
# ## Longitude and Latitude Based On Capital City

# %%
import requests
def get_json_from_capital(value):
    url = f"https://geocoding-api.open-meteo.com/v1/search?name={value}&count=1&language=en&format=json"
    response = requests.get(url)
    return response.json()

# %%
result_json = []
for i in indProv:
    result_json.append(get_json_from_capital(i['ibukota']))

# %%
print(result_json)
# Out:
# [{'results': [{'id': 1215502, 'name': 'Banda Aceh', 'latitude': 5.54167, 'longitude': 95.33333, 'elevation': 9.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1215638, 'admin2_id': 1215501, 'timezone': 'Asia/Jakarta', 'population': 250757, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Aceh', 'admin2': 'Kota Banda Aceh'}], 'generationtime_ms': 1.0859966}, {'results': [{'id': 1214520, 'name': 'Medan', 'latitude': 3.58333, 'longitude': 98.66667, 'elevation': 26.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1213642, 'timezone': 'Asia/Jakarta', 'population': 1750971, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'North Sumatra'}], 'generationtime_ms': 1.7809868}, {'results': [{'id': 1633419, 'name': 'Padang', 'latitude': -0.94924, 'longitude': 100.35427, 'elevation': 6.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1626197, 'timezone': 'Asia/Jakarta', 'population': 840352, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'West Sumatra'}], 'generationtime_ms': 4.4549704}, {'results': [{'id': 1631761, 'name': 'Pekanbaru', 'latitude': 0.51667, 'longitude': 101.44167, 'elevation': 19.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1629652, 'timezone': 'Asia/Jakarta', 'population': 703956, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Riau'}], 'generationtime_ms': 0.7530451}, {'results': [{'id': 1642858, 'name': 'Jambi City', 'latitude': -1.6, 'longitude': 103.61667, 'elevation': 21.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1642856, 'timezone': 'Asia/Jakarta', 'population': 420323, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Jambi'}], 'generationtime_ms': 1.3320446}, {'results': [{'id': 1633070, 'name': 'Palembang', 'latitude': -2.91673, 'longitude': 104.7458, 'elevation': 5.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1626196, 'timezone': 'Asia/Jakarta', 'population': 1441500, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'South Sumatra'}], 'generationtime_ms': 2.1970272}, {'results': [{'id': 1649150, 'name': 'Bengkulu', 'latitude': -3.80044, 'longitude': 102.26554, 'elevation': 19.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1649147, 'timezone': 'Asia/Jakarta', 'population': 309712, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Bengkulu'}], 'generationtime_ms': 1.447916}, {'results': [{'id': 1624917, 'name': 'Bandar Lampung', 'latitude': -5.42917, 'longitude': 105.26111, 'elevation': 95.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1638535, 'timezone': 'Asia/Jakarta', 'population': 800348, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Lampung'}], 'generationtime_ms': 1.0210276}, {'results': [{'id': 1632654, 'name': 'Pangkalpinang', 'latitude': -2.12914, 'longitude': 106.11377, 'elevation': 10.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1923047, 'timezone': 'Asia/Jakarta', 'population': 125933, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Bangka–Belitung Islands'}], 'generationtime_ms': 1.5799999}, {'results': [{'id': 1624863, 'name': 'Tanjung Pinang', 'latitude': 0.91667, 'longitude': 104.45833, 'elevation': 39.0, 'feature_code': 'PPLA2', 'country_code': 'ID', 'admin1_id': 1996551, 'timezone': 'Asia/Jakarta', 'population': 192493, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Riau Islands'}], 'generationtime_ms': 2.4288893}, {'results': [{'id': 1642911, 'name': 'Batavia', 'latitude': -6.21462, 'longitude': 106.84513, 'elevation': 16.0, 'feature_code': 'PPLC', 'country_code': 'ID', 'admin1_id': 1642907, 'timezone': 'Asia/Jakarta', 'population': 8540121, 'country_id': 1643084, 'country': 'Indonesia', 'admin1': 'Jakarta'}], 'generationtime_ms': 0.9379387}, {'results': [{'id': 1650357, 'name': 'Bandung', 'latitude': -6.92222, 'longitude': 107.60694, 'elevation': 714.0, 'feature_code': 'PPLA', 'country_code': 'ID', 'admin1_id': 1642672, 'timezone': 'Asia/Jakarta', 'population': 16 ...

# %%
# result_json[36], len(result_json), indProv[36]
# for i in range(len(result_json)):
#     if 'generationtime_ms' in result_json[i]:
#         print(result_json[i], i)
    # print(result_json[i], i)

# %%
# save data request to numpy array
import numpy as np

result_json_array = np.array(result_json)
np.save('temp/requests_json_array.npy', result_json_array)

# %%
import json

# iterate json array to combine with indProv
for index in range(len(result_json)):
    json_string = json.dumps(result_json[index])
    data = json.loads(json_string)
    if 'results' in data and len(data['results']) > 0:
        res = data['results'][0]
        country = res['country']
        latitude = res['latitude']
        longitude = res['longitude']

        indProv[index]['country'] = country
        indProv[index]['latitude'] = latitude
        indProv[index]['longitude'] = longitude
    else:
        print(index)

        # if next((index for index, province in enumerate(indProv) if province.get('ibukota').lower() in res['name'].lower()), None) == None:
        #     print(i)

# %%
# saved_data_indprov_withlonglat
np.save('temp/ind_prov_longlat.npy', indProv)

# %% [markdown]
# ## Get the weather informations between date first januari until 17 agustus 2024

# %%
import requests
def get_weather_from_longlat(longitude, latitude):
    url = f"https://api.open-meteo.com/v1/forecast?latitude={latitude}&longitude={longitude}&daily=weather_code,temperature_2m_max,temperature_2m_min,sunrise,sunset,daylight_duration,sunshine_duration,uv_index_max,uv_index_clear_sky_max,wind_speed_10m_max,wind_direction_10m_dominant&timezone=Asia%2FBangkok&start_date=2024-01-01&end_date=2024-08-16"
    response = requests.get(url)
    return response.json()

# %%
for index in range(len(indProv)):
    weather_data = get_weather_from_longlat(indProv[index]['longitude'], indProv[index]['latitude'])
    capital = indProv[index]['ibukota']
    with open(f'temp/json_d/{index+1}_{capital}.json', 'w') as json_file:
        json.dump(weather_data, json_file, indent=4)

# weather_data = get_weather_from_longlat(indProv[0]['longitude'], indProv[0]['latitude'])
# weather_data

# %%
# higher than 25 start from sorong is had a limited api call
